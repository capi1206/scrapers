# %% [markdown]
# ## NOTEBOOK `doctorolia`

# %% [markdown]
# #### Se navega a `https://www.doctoralia.co/especialidades-medicas` se extraen todos los enlaces de especialdidades,
# #### identificados por contener el texto `Ver mas` (este es selector 1, nivel 1 de profundidad), se guarda cada uno de los enlaces.
# #### En cada uno de estos enlaces hay elementos `<a>` que tienen un respectivo enlace ( `href` selector 2, en nivel 2) con un texto relativo a la especilidad en la que se esta navegando, se deben guardar estos enlaces.
# #### En cada una de estas paginas existe informacion de doctores, algunas tienen varias pesta'nas de navegacion.

# %%
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeoutError
import asyncio
import nest_asyncio

# --- CONFIGURATION ---
# The specific page listing medical specialties
URL = "https://www.doctoralia.co/especialidades-medicas"
# Selector targeting an anchor tag <a> that contains the exact visible text "ver más"
# This reliably finds the elements you are interested in.
LINK_SELECTOR = 'a:has-text("ver más")' 
# Common selector for cookie acceptance banners
COOKIE_ACCEPT_SELECTOR = 'text="Aceptar"'
# ---------------------

async def extract_ver_mas_links(url, selector):
    """
    Navigates to the specified URL and extracts the 'href' attribute 
    from all anchor tags containing the text 'ver más'.
    
    Args:
        url (str): The target URL to scrape.
        selector (str): The CSS selector used to locate the links.

    Returns:
        list: A list of strings, where each string is an extracted URL.
    """
    print(f"Starting extraction process for URL: {url}")
    print(f"Looking for elements matching selector: {selector}")
    extracted_urls = []

    async with async_playwright() as p:
        # Launching the browser in headless mode for efficiency
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        try:
            # Navigate to the page and wait for the DOM and network to settle
            await page.goto(url, wait_until="domcontentloaded", timeout=30000)
            await page.wait_for_load_state('networkidle')

            # 1. Handle Cookie Consent (Crucial for interaction stability)
            try:
                cookie_button = page.locator(COOKIE_ACCEPT_SELECTOR)
                # Check for visibility and click if it exists
                if await cookie_button.is_visible(timeout=5000):
                    await cookie_button.click()
                    print("Cookie consent accepted successfully.")
                    await page.wait_for_timeout(500)
            except PlaywrightTimeoutError:
                # If the button doesn't appear within the timeout, gracefully ignore
                pass 
            
            # 2. Locate and Extract Links
            link_locators = page.locator(selector)
            count = await link_locators.count()
            print(f"Found {count} elements matching the selector.")

            # Efficiently extract the 'href' attribute from all located elements 
            # using Playwright's evaluate_all method (running JavaScript in the browser context)
            urls = await link_locators.evaluate_all('elements => elements.map(e => e.href)')
            
            # 3. Clean up the extracted list
            extracted_urls = [url.strip() for url in urls if url and url.strip()]
            
        except PlaywrightTimeoutError:
            print(f"\n[ERROR] Playwright Timeout occurred during navigation or waiting.")
        except Exception as e:
            print(f"\n[CRITICAL ERROR] An unexpected error occurred: {e}")

        finally:
            await browser.close()
            print("\nBrowser closed.")
            
    return extracted_urls

if __name__ == "__main__":
    
    # Use nest_asyncio to allow asyncio.run in interactive/notebook environments
    try:
        nest_asyncio.apply()
    except Exception:
        pass

    # Execute the main asynchronous function
    links = asyncio.run(extract_ver_mas_links(URL, LINK_SELECTOR))
    
    if links:
        print("\n--- Extracted Landing URLs ('ver más') ---")
        for i, link in enumerate(links, 1):
            print(f"{i}. {link}")
        print(f"\nTotal unique links extracted: {len(set(links))}")
    else:
        print("\nNo links were extracted or an error occurred.")
# Out:
# Starting extraction process for URL: https://www.doctoralia.co/especialidades-medicas
# Looking for elements matching selector: a:has-text("ver más")
# Found 98 elements matching the selector.
#
# Browser closed.
#
# --- Extracted Landing URLs ('ver más') ---
# 1. https://www.doctoralia.co/especialidades-medicas/en-detalle/alergologo
# 2. https://www.doctoralia.co/especialidades-medicas/en-detalle/alergologo-pediatrico
# 3. https://www.doctoralia.co/especialidades-medicas/en-detalle/anestesiologo
# 4. https://www.doctoralia.co/especialidades-medicas/en-detalle/audiologo
# 5. https://www.doctoralia.co/especialidades-medicas/en-detalle/auxiliar-de-enfermeria
# 6. https://www.doctoralia.co/especialidades-medicas/en-detalle/cardiologo
# 7. https://www.doctoralia.co/especialidades-medicas/en-detalle/cardiologo-pediatrico
# 8. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-cardiovascular
# 9. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-de-cabeza-y-cuello
# 10. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-de-mama-y-tejidos-blandos
# 11. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-de-torax
# 12. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-general
# 13. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-maxilofacial
# 14. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-oncologo
# 15. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-pediatrico
# 16. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-plastico
# 17. https://www.doctoralia.co/especialidades-medicas/en-detalle/cirujano-vascular
# 18. https://www.doctoralia.co/especialidades-medicas/en-detalle/coloproctologo
# 19. https://www.doctoralia.co/especialidades-medicas/en-detalle/dermatologo
# 20. https://www.doctoralia.co/especialidades-medicas/en-detalle/dermatologo-pediatrico
# 21. https://www.doctoralia.co/especialidades-medicas/en-detalle/endocrinologo
# 22. https://www.doctoralia.co/especialidades-medicas/en-detalle/endocrinologo-pediatrico
# 23. https://www.doctoralia.co/especialidades-medicas/en-detalle/enfermero
# 24. https://www.doctoralia.co/especialidades-medicas/en-detalle/epidemiologo
# 25. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-cuidados-criticos
# 26. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-medicina-aerospacial
# 27. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-medicina-de-urgencias
# 28. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-medicina-deportiva
# 29. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-medicina-domiciliaria
# 30. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-medicina-familiar
# 31. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-medicina-nuclear
# 32. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-salud-publica
# 33. https://www.doctoralia.co/especialidades-medicas/en-detalle/especialista-en-tratamiento-del-dolor
# 34. https://www.doctoralia.co/especialidades-medicas/en-detalle/fisioterapeuta
# 35. https://www.doctoralia.co/especialidades-medicas/en-detalle/fonoaudiologo
# 36. https://www.doctoralia.co/especialidades-medicas/en-detalle/gastroenterologo
# 37. https://www.doctoralia.co/especialidades-medicas/en-detalle/gastroenterologo-pediatrico
# 38. https://www.doctoralia.co/especialidades-medicas/en-detalle/genetista
# 39. https://www.doctoralia.co/especialidades-medicas/en-detalle/geriatra
# 40. https://www.doctoralia.co/especialidades-medicas/en-detalle/ginecologo
# 41. https://www.doctoralia.co/especialidades-medicas/en-detalle/hematologo
# 42. https://www.doctoralia.co/especialidades-medicas/en-detalle/hepatologo
# 43. https://www.doctoralia.co/especialidades-medicas/en-detalle/homeopata
# 44. https://www.doctoralia.co/especialidades-medicas/en-detalle/infectologo
# 45. https://www.doctoralia.co/especialidades-medicas/en-detalle/infectologo-pediatra
# 46. https://www.doctoralia.co/especialidades-medicas/en-detalle/internista
# 47. https://www.doctoralia.co/especialidades-medicas/en-detalle/mastologo
# 48. https://www.doctoralia.co/especialidades-medicas/en-detalle/medico-alternativo
# 49. https://www.doctoralia.co/especialidades-medicas/en-detalle/medico-estetico
# 50. https://www.doctoralia.co/especialidades-medicas/en-detalle/medico-fisiatra-rehabilitador
# 51. https://www.doctoralia.co/especialidades-medicas/en-detalle/medico-general
# 52. https://www.doctoralia.co/especialidades-medicas/en-detalle/medico-laboral
# 53. https://www.doctoralia.co/especialidades-medicas/en-detalle/nefrologo
# 54. https://www.doctoralia.co/especialidades-medicas/en-detalle/nefrologo-pediatra
# 55. https://www.doctoralia.co/especialidades-medicas/en-detalle/neonatologo
# 56. https://www.doctoralia.co/especialidades-medicas/en-detalle/neumologo
# 57. https://www.doctoralia.co/especialidades-medicas/en-detalle/neumologo-pediatrico
# 58. https://www.doctoralia.co/especialidades-medicas/en-detalle/neuro-oftalmologo
# 59. https://www.doctoralia.co/especialidades-medicas/en-detalle/neurocirujano
# 60. https://www.doctoralia.co/especialidades-medicas/en-detalle/neurofisiologo
# 61. https://www.doctoralia.co/especialidades-medicas/en-detalle/neurologo
# 62. https://www.doctoralia.co/especialidades-medicas/en-detalle/neurologo-pediatra
# 63. https://www.doctoralia.co/especialidades-medicas/en-detalle/neuropsicologo
# 64. https://www.doctoralia.co/especialidades-medicas/en-detalle/nutricionista
# 65. https://www.doctoralia.co/especialidades-medicas/en-detalle/nutriologo
# 66. https://www.doctoralia.co/especialidades-medicas/en-detalle/odontologo
# 67. https://www.doctoralia.co/especialidades-medicas/en-detalle/odontopediatra
# 68. https://www.doctoralia.co/especialidades-medicas/en-detalle/oftalmologo
# 69. https://www.doctoralia.co/especialidades-medicas/en-detalle/oftalmologo-pediatrico
# 70. https://www.doctoralia.co/especialidades-medicas/en-detalle/oncologo
# 71. https://www.doctoralia.co/especialidades-medicas/en-detalle/oncologo-pediatrico
# 72. https://www.doctoralia.co/especialidades-medicas/en-detalle/oncologo-radioterapico
# 73. https://www.doctoralia.co/especialidades-medicas/en-detalle/optometra
# 74. https://www.doctoralia.co/especialidades-medicas/en-detalle/ortodoncista
# 75. https://www.doctoralia.co/especialidades-medicas/en-detalle/ortopedista-infantil
# 76. https://www.doctoralia.co/especialidades-medicas/en-detalle/ortopedista-y-traumatologo
# 77. https://www.doctoralia.co/especialidades-medicas/en-detalle/otorrinolaringologo
# 78. https://www.doctoralia.co/especialidades-medicas/en-detalle/patologo
# 79. https://www.doctoralia.co/especialidades-medicas/en-detalle/pediatra
# 80. https://www.doctoralia.co/especialidades-medicas/en-detalle/perinatologo
# 81. https://www.doctoralia.co/especialidades-medicas/en-detalle/podologo
# 82. https://www.doctoralia.co/especialidades-medicas/en-detalle/proctologo
# 83. https://www.doctoralia.co/especialidades-medicas/en-detalle/psicoanalista
# 84. https://www.doctoralia.co/especialidades-medicas/en-detalle/psicologo
# 85. https://www.doctoralia.co/especialidades-medicas/en-detalle/psicopedagogo
# 86. https://www.doctoralia.co/especialidades-medicas/en-detalle/psiquiatra
# 87. https://www.doctoralia.co/especialidades-medicas/en-detalle/psiquiatra-infantil
# 88. https://www.doctoralia.co/especialidades-medicas/en-detalle/radiologo
# 89. https://www.doctoralia.co/especialidades-medicas/en-detalle/radioterapeuta
# 90. https://www.doctoralia.co/especialidades-medicas/en-detalle/reumatologo
# 91. https://www.doctoralia.co/especialidades-medicas/en-detalle/reumatologo-pediatrico
# 92. https://www.doctoralia.co/especialidades-medicas/en-detalle/sexologo
# 93. https://www.doctoralia.co/especialidades-medicas/en-detalle/tecnico-en-laboratorio-clinico
# 94. https://www.doctoralia.co/especialidades-medicas/en-detalle/terapeuta-complementario
# 95. https://www.doctoralia.co/especialidades-medicas/en-detalle/terapeuta-ocupacional
# 96. https://www.doctoralia.co/especialidades-medicas/en-detalle/terapeuta-respiratorio
# 97. https://www.doctoralia.co/especialidades-medicas/en-detalle/toxicologo
# 98. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
#
# Total unique links extracted: 98

# %%
substring = "aler"
LINK_SELECTOR = f'a:has-text("{substring}")' 

URL = "https://www.doctoralia.co/especialidades-medicas/en-detalle/alergologo"
if True: #__name__ == "__main__":
    
    # Use nest_asyncio to allow asyncio.run in interactive/notebook environments
    try:
        nest_asyncio.apply()
    except Exception:
        pass

    # Execute the main asynchronous function
    deep_links_1 = asyncio.run(extract_ver_mas_links(URL, LINK_SELECTOR))
    
    if links:
        print("\n--- Extracted Alergólogo/City Landing URLs ---")
        # Print the first 10 links for verification
        for i, linj in enumerate(deep_links_1[:10], 1):
            print(f"{i}. {link}")
        
        # Give a summary of the count
        if len(links) > 10:
             print(f"\n... and {len(links) - 10} more links.")
        print(f"Total unique links extracted: {len(set(links))}")
    else:
        print("\nNo links were extracted or an error occurred.")
# Out:
# Starting extraction process for URL: https://www.doctoralia.co/especialidades-medicas/en-detalle/alergologo
# Looking for elements matching selector: a:has-text("aler")
# Found 28 elements matching the selector.
#
# Browser closed.
#
# --- Extracted Alergólogo/City Landing URLs ---
# 1. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 2. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 3. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 4. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 5. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 6. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 7. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 8. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 9. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 10. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
#
# ... and 88 more links.
# Total unique links extracted: 98

# %%
substring = "aler"
LINK_SELECTOR = f'a:has-text("{substring}")' 

URL = "https://www.doctoralia.co/especialidades-medicas/en-detalle/alergologo"
if True: #__name__ == "__main__":
    
    # Use nest_asyncio to allow asyncio.run in interactive/notebook environments
    try:
        nest_asyncio.apply()
    except Exception:
        pass

    # Execute the main asynchronous function
    deep_links_1 = asyncio.run(extract_ver_mas_links(URL, LINK_SELECTOR))
    
    if links:
        print("\n--- Extracted Alergólogo/City Landing URLs ---")
        # Print the first 10 links for verification
        for i, linj in enumerate(deep_links_1[:10], 1):
            print(f"{i}. {link}")
        
        # Give a summary of the count
        if len(links) > 10:
             print(f"\n... and {len(links) - 10} more links.")
        print(f"Total unique links extracted: {len(set(links))}")
    else:
        print("\nNo links were extracted or an error occurred.")
# Out:
# Starting extraction process for URL: https://www.doctoralia.co/especialidades-medicas/en-detalle/alergologo
# Looking for elements matching selector: a:has-text("aler")
# Found 28 elements matching the selector.
#
# Browser closed.
#
# --- Extracted Alergólogo/City Landing URLs ---
# 1. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 2. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 3. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 4. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 5. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 6. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 7. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 8. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 9. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
# 10. https://www.doctoralia.co/especialidades-medicas/en-detalle/urologo
#
# ... and 88 more links.
# Total unique links extracted: 98
